# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import matplotlib_inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:\\Users\\s\\OneDrive\\Desktop\\Data Science\\DATA SCIENCE\\MACHINE LEARNING\\PROJECTS\\REGRESSION\\data.csv")

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df["city"].unique()
# Out:
# array(['Shoreline', 'Seattle', 'Kent', 'Bellevue', 'Redmond',
#        'Maple Valley', 'North Bend', 'Lake Forest Park', 'Sammamish',
#        'Auburn', 'Des Moines', 'Bothell', 'Federal Way', 'Kirkland',
#        'Issaquah', 'Woodinville', 'Normandy Park', 'Fall City', 'Renton',
#        'Carnation', 'Snoqualmie', 'Duvall', 'Burien', 'Covington',
#        'Inglewood-Finn Hill', 'Kenmore', 'Newcastle', 'Mercer Island',
#        'Black Diamond', 'Ravensdale', 'Clyde Hill', 'Algona', 'Skykomish',
#        'Tukwila', 'Vashon', 'Yarrow Point', 'SeaTac', 'Medina',
#        'Enumclaw', 'Snoqualmie Pass', 'Pacific', 'Beaux Arts Village',
#        'Preston', 'Milton'], dtype=object)

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %% [markdown]
# ### feature Engineering

# %%
## Label encoding

from sklearn.preprocessing import LabelEncoder

# %%
labelencoder=LabelEncoder()

# %%
df['city']=labelencoder.fit_transform(df['city'])
df['street']=labelencoder.fit_transform(df['street'])
df['statezip']=labelencoder.fit_transform(df['statezip'])
df['country']=labelencoder.fit_transform(df['country'])

# %%
df['bedrooms']=df['bedrooms'].astype('int')
df['bathrooms']=df['bathrooms'].astype('int')

# %% [markdown]
# #### Onehotencoding with many categories in a feature

# %%
df_final1=pd.read_csv("C:\\Users\\s\\OneDrive\\Desktop\\Data Science\\DATA SCIENCE\\MACHINE LEARNING\\PROJECTS\\REGRESSION\\data.csv")

# %%
df_final1.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df_final1=df_final1.drop('date',axis=1)

# %%
for i in df_final1.columns:
    print(df_final1[i].value_counts())
# Out:
# 0.0          49
# 300000.0     42
# 400000.0     31
# 440000.0     29
# 450000.0     29
#              ..
# 684680.0      1
# 609900.0      1
# 1635000.0     1
# 1339000.0     1
# 220600.0      1
# Name: price, Length: 1741, dtype: int64
# 3.0    2032
# 4.0    1531
# 2.0     566
# 5.0     353
# 6.0      61
# 1.0      38
# 7.0      14
# 8.0       2
# 0.0       2
# 9.0       1
# Name: bedrooms, dtype: int64
# 2.50    1189
# 1.00     743
# 1.75     629
# 2.00     427
# 2.25     419
# 1.50     291
# 2.75     276
# 3.00     167
# 3.50     162
# 3.25     136
# 3.75      37
# 4.50      29
# 4.25      23
# 4.00      23
# 0.75      17
# 4.75       7
# 5.00       6
# 5.25       4
# 5.50       4
# 1.25       3
# 6.25       2
# 0.00       2
# 8.00       1
# 5.75       1
# 6.50       1
# 6.75       1
# Name: bathrooms, dtype: int64
# 1940     32
# 1720     32
# 1660     31
# 1840     31
# 2000     30
#          ..
# 2732      1
# 2009      1
# 1295      1
# 10040     1
# 2538      1
# ...

# %%
df_final1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          4600 non-null   float64
#  1   bedrooms       4600 non-null   float64
#  2   bathrooms      4600 non-null   float64
#  3   sqft_living    4600 non-null   int64
#  4   sqft_lot       4600 non-null   int64
#  5   floors         4600 non-null   float64
#  6   waterfront     4600 non-null   int64
#  7   view           4600 non-null   int64
#  8   condition      4600 non-null   int64
#  9   sqft_above     4600 non-null   int64
#  10  sqft_basement  4600 non-null   int64
#  11  yr_built       4600 non-null   int64
#  12  yr_renovated   4600 non-null   int64
#  13  street         4600 non-null   object
#  14  city           4600 non-null   object
#  15  statezip       4600 non-null   object
#  16  country        4600 non-null   object
# ...

# %%
df_final1.street.value_counts()
# Out:
# 2520 Mulberry Walk NE     4
# 2500 Mulberry Walk NE     3
# 9413 34th Ave SW          2
# 6008 8th Ave NE           2
# 11034 NE 26th Pl          2
#                          ..
# 1404 Broadmoor Dr E       1
# 3249 E Ames Lake Dr NE    1
# 6032 35th Ave NE          1
# 1006 NE Ravenna Blvd      1
# 18717 SE 258th St         1
# Name: street, Length: 4525, dtype: int64

# %%
df_final1.street.value_counts().sort_values(ascending=False).head(10)
# Out:
# 2520 Mulberry Walk NE      4
# 2500 Mulberry Walk NE      3
# 619 9th Ave                2
# Burke-Gilman Trail         2
# 12303 Sand Point Way NE    2
# 513 N 46th St              2
# 1610 N 185th St            2
# 23620 SE 243rd Pl          2
# 34809 SE Garden Ct         2
# 14634 128th Ave NE         2
# Name: street, dtype: int64

# %%
### there is no much repeated values

# %%
df_final1.groupby(['street'])['price'].mean()
# Out:
# street
# 1 View Ln NE           309620.0
# 10 W Etruria St        625000.0
# 100 20th Ave E         600000.0
# 100 24th Ave E         460000.0
# 100 Mt Si Pl NW        575000.0
#                          ...
# Shangri-La Way NW      627000.0
# Sunrise Loop Trail     754800.0
# Tolt Pipeline Trail    435000.0
# Trossachs Blvd SE      735000.0
# Valley View Trail      693000.0
# Name: price, Length: 4525, dtype: float64

# %%
df_final1.groupby(['street'])['price'].mean().sort_values().index
# Out:
# Index(['3665 50th Ave NE', '2 Crescent Key', '101-127 247th Ave SE',
#        '4500 NE 171st St', '16232 SE 10th St', '2760 72nd Ave SE',
#        '10744 62nd Ave S', '27622 237th Pl SE', '12725 8th Ave NW',
#        '3911 S 328th St',
#        ...
#        '1291 NW Elford Dr', '11031 Champagne Point Rd NE',
#        '5243 Forest Ave SE', '1230 Warren Ave N', '3222 78th Pl NE',
#        '1365 91st Ave NE', '5044 Butterworth Rd', '4442 95th Ave NE',
#        '5426 40th Ave W', '12005 SE 219th Ct'],
#       dtype='object', name='street', length=4525)

# %%
ordinal_labels=df_final1.groupby(['street'])['price'].mean().sort_values().index

# %%
ordinal_labels
# Out:
# Index(['3665 50th Ave NE', '2 Crescent Key', '101-127 247th Ave SE',
#        '4500 NE 171st St', '16232 SE 10th St', '2760 72nd Ave SE',
#        '10744 62nd Ave S', '27622 237th Pl SE', '12725 8th Ave NW',
#        '3911 S 328th St',
#        ...
#        '1291 NW Elford Dr', '11031 Champagne Point Rd NE',
#        '5243 Forest Ave SE', '1230 Warren Ave N', '3222 78th Pl NE',
#        '1365 91st Ave NE', '5044 Butterworth Rd', '4442 95th Ave NE',
#        '5426 40th Ave W', '12005 SE 219th Ct'],
#       dtype='object', name='street', length=4525)

# %%
enumerate(ordinal_labels,0)

# %%
ordinal_labels2={k:i for i,k in enumerate(ordinal_labels,0)}
ordinal_labels2
# Out:
# {'3665 50th Ave NE': 0,
#  '2 Crescent Key': 1,
#  '101-127 247th Ave SE': 2,
#  '4500 NE 171st St': 3,
#  '16232 SE 10th St': 4,
#  '2760 72nd Ave SE': 5,
#  '10744 62nd Ave S': 6,
#  '27622 237th Pl SE': 7,
#  '12725 8th Ave NW': 8,
#  '3911 S 328th St': 9,
#  '39612 254th Ave SE': 10,
#  '1013 NE 80th St': 11,
#  '14901-14999 12th Ave SW': 12,
#  '1301-1303 Monterey Ave NE': 13,
#  '2120 31st Ave W': 14,
#  '506 21st St SE': 15,
#  '11533 22nd Ave NE': 16,
#  '30401-30499 8th Ave SW': 17,
#  '6925 Oakmont Ave SE': 18,
#  '21418 SE 5th Pl': 19,
#  '11620-11698 57th Ave S': 20,
#  '216 SW 183rd St': 21,
#  '21809 SE 38th Pl': 22,
#  '4115 85th Ave SE': 23,
#  '4140 Boulevard Pl': 24,
#  '2234 167th Ave SE': 25,
#  '29656 232nd Ave SE': 26,
#  '13505 208th Ave NE': 27,
#  '425 E Lake Sammamish Pkwy SE': 28,
#  '7455 W Mercer Way': 29,
#  '3202 S 194th St': 30,
#  '1236 S Cloverdale St': 31,
#  '31603 E Lake Morton Dr SE': 32,
#  '1223-1237 244th Ave NE': 33,
# ...

# %%
df_final1['street_ordinal']=df['street'].map(ordinal_labels2)
df_final1.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#                      street       city  statezip country  street_ordinal
# ...

# %%
df=df.drop(['date'],axis=1)

# %%
## feature engineering
##df['Year']=df['date'].str.split('/').str[0]
#df['Month']=df['date'].str.split('/').str[1]
#df['Date']=df['date'].str.split('/').str[2]
#df['Time']=df['date'].str.split('/').str[3]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          4600 non-null   float64
#  1   bedrooms       4600 non-null   int32
#  2   bathrooms      4600 non-null   int32
#  3   sqft_living    4600 non-null   int64
#  4   sqft_lot       4600 non-null   int64
#  5   floors         4600 non-null   float64
#  6   waterfront     4600 non-null   int64
#  7   view           4600 non-null   int64
#  8   condition      4600 non-null   int64
#  9   sqft_above     4600 non-null   int64
#  10  sqft_basement  4600 non-null   int64
#  11  yr_built       4600 non-null   int64
#  12  yr_renovated   4600 non-null   int64
#  13  street         4600 non-null   int32
#  14  city           4600 non-null   int32
#  15  statezip       4600 non-null   int32
#  16  country        4600 non-null   int32
# dtypes: float64(2), int32(6), int64(9)
# ...

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3          1         1340      7912     1.5           0
# 1  2384000.0         5          2         3650      9050     2.0           0
# 2   342000.0         3          2         1930     11947     1.0           0
# 3   420000.0         3          2         2000      8030     1.0           0
# 4   550000.0         4          2         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  street  \
# 0     0          3        1340              0      1955          2005    1522
# 1     4          5        3370            280      1921             0    3899
# 2     0          4        1930              0      1966             0    2291
# 3     0          4        1000           1000      1963             0    4263
# 4     0          4        1140            800      1976          1992    4352
#
#    city  statezip  country
# ...

# %% [markdown]
# ## Featur selection

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(df, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(df, 0.8)
len(set(corr_features))
# Out:
# 1

# %%
df.drop(corr_features,axis=1)
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05         3          1         1340      7912     1.5
# 1     2.384000e+06         5          2         3650      9050     2.0
# 2     3.420000e+05         3          2         1930     11947     1.0
# 3     4.200000e+05         3          2         2000      8030     1.0
# 4     5.500000e+05         4          2         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05         3          1         1510      6360     1.0
# 4596  5.343333e+05         3          2         1460      7573     2.0
# 4597  4.169042e+05         3          2         3010      7014     2.0
# 4598  2.034000e+05         4          2         2090      6630     1.0
# 4599  2.206000e+05         3          2         1490      8102     2.0
#
#       waterfront  view  condition  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
corr_features
# Out:
# {'sqft_above'}

# %% [markdown]
# ### Data visualization

# %%
sns.pairplot(df)

# %% [markdown]
# ### checking for outliers

# %%
figure1=df.street.hist(bins=500)
figure1.set_title('street')
# Out:
# Text(0.5, 1.0, 'street')

# %%
figure1=df.boxplot(column="street")

# %%
figure2=df.city.hist(bins=100)
figure2.set_title("city")
# Out:
# Text(0.5, 1.0, 'city')

# %%
figure2=df.boxplot(column='city')

# %%
X=df.drop(['price'],axis=1)
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 4351         2          1          780     16344     1.0           0     0
# 3560         3          1          910      8789     1.0           0     0
# 2589         4          2         1740      7500     1.0           0     0
# 3062         3          2         1100       750     2.0           0     0
# 4434         4          2         2320      4344     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 4426         3          1         1180      5002     1.5           0     0
# 466          4          2         2520      6000     1.0           0     0
# 3092         3          1         1150      8145     1.0           0     0
# 3772         2          1          910      2002     1.5           0     0
# 860          2          1         1490      3825     1.0           0     0
#
# ...

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()

# %%
X_train=scalar.fit_transform(X_train)
X_test=scalar.transform(X_test)

# %% [markdown]
# ### Algoritms

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg_linear=LinearRegression()

# %%
reg_linear.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_linear_pred=reg_linear.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,y_train_linear_pred)
# Out:
# 0.5508838008155801

# %%
y_test_linear_pred=reg_linear.predict(X_test)

# %%
r2_score(y_test,y_test_linear_pred)
# Out:
# 0.06691716526636626

# %% [markdown]
# #### Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
reg_ridge=Ridge()

# %%
reg_ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
y_train_ridge_pred=reg_ridge.predict(X_train)

# %%
r2_score(y_train,y_train_ridge_pred)
# Out:
# 0.5510000391982904

# %%
y_test_linear_reg=reg_ridge.predict(X_test)

# %%
r2_score(y_test,y_test_linear_reg)
# Out:
# 0.06754925603097839

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
reg_knn=KNeighborsRegressor()

# %%
reg_knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_train_knn_pred=reg_knn.predict(X_train)

# %%
r2_score(y_train,y_train_knn_pred)
# Out:
# 0.6534029756992257

# %%
y_test_knn_pred=reg_knn.predict(X_test)

# %%
r2_score(y_test,y_test_knn_pred)
# Out:
# 0.05910877242467172

# %%
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor()

# %%
reg.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Train accuracy

# %%
y_train_pred=reg.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.9483868545267199

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_train,y_train_pred)
# Out:
# 7564715692.219825

# %%
np.sqrt(mean_squared_error(y_train,y_train_pred))
# Out:
# 86975.37405622251

# %% [markdown]
# ## Test accuracy

# %%
y_test_pred=reg.predict(X_test)

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.08238454141658147

# %%
mean_squared_error(y_test,y_test_pred)
# Out:
# 610632738262.8761

# %%
np.sqrt(mean_squared_error(y_test,y_test_pred))
# Out:
# 781429.9317679583

# %%
plt.scatter(y_test,y_test_pred)

# %%
sns.displot(y_test_pred)

# %% [markdown]
# ## Pickling The Model file For Deployment

# %%
import pickle

# %%
pickle.dump(reg,open('regmodel','wb'))

# %%
df.head(2)
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3          1         1340      7912     1.5           0
# 1  2384000.0         5          2         3650      9050     2.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  street  \
# 0     0          3        1340              0      1955          2005    1522
# 1     4          5        3370            280      1921             0    3899
#
#    city  statezip  country
# 0    36        62        0
# 1    35        58        0

# %%
X.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'street', 'city', 'statezip', 'country'],
#       dtype='object')

# %%
reg.predict([[3,2,345,798,2,0,4,4,344,0,1998,2020,123,36,56,0]])
# Out:
# C:\Users\s\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([292084.])

# %%
pickle_model=pickle.load(open('regmodel','rb'))

# %%
pickle_model.predict([[3,2,345,798,2,0,4,4,344,0,1998,2020,123,36,56,0]])
# Out:
# C:\Users\s\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([292084.])
